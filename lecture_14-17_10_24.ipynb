# %%
import pandas as pd

# %%
df = pd.read_csv("Filtered_Squirrel_Data.csv")

# %%
df.shape
# Out:
# (3023, 31)

# %%
#relative path: göreceli yol, nerde oldugumuza göre degisir. yani oldugun yerdeki dosya adini direkt yazma da diyebiliriz
#absolute path: mutlak yol, nerde olursak olalim en bastan itibaren butun dosyalari verir

# %%
df.head()
# Out:
#            X          Y Unique Squirrel ID Hectare Shift      Date  \
# 0 -73.956134  40.794082     37F-PM-1014-03     37F    PM  10142018
# 1 -73.957044  40.794851     37E-PM-1006-03     37E    PM  10062018
# 2 -73.976831  40.766718      2E-AM-1010-03     02E    AM  10102018
# 3 -73.975725  40.769703      5D-PM-1018-05     05D    PM  10182018
# 4 -73.959313  40.797533     39B-AM-1018-01     39B    AM  10182018
#
#    Hectare Squirrel Number       Age Primary Fur Color Highlight Fur Color  \
# 0                        3       NaN               NaN                 NaN
# 1                        3     Adult              Gray            Cinnamon
# 2                        3     Adult          Cinnamon                 NaN
# 3                        5  Juvenile              Gray                 NaN
# 4                        1       NaN               NaN                 NaN
#
#   Combination of Primary and Highlight Color Color notes      Location  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of               X          Y Unique Squirrel ID Hectare Shift      Date  \
# 0    -73.956134  40.794082     37F-PM-1014-03     37F    PM  10142018
# 1    -73.957044  40.794851     37E-PM-1006-03     37E    PM  10062018
# 2    -73.976831  40.766718      2E-AM-1010-03     02E    AM  10102018
# 3    -73.975725  40.769703      5D-PM-1018-05     05D    PM  10182018
# 4    -73.959313  40.797533     39B-AM-1018-01     39B    AM  10182018
# ...         ...        ...                ...     ...   ...       ...
# 3018 -73.963943  40.790868     30B-AM-1007-04     30B    AM  10072018
# 3019 -73.970402  40.782560     19A-PM-1013-05     19A    PM  10132018
# 3020 -73.966587  40.783678     22D-PM-1012-07     22D    PM  10122018
# 3021 -73.963994  40.789915     29B-PM-1010-02     29B    PM  10102018
# 3022 -73.975479  40.769640      5E-PM-1012-01     05E    PM  10122018
#
#       Hectare Squirrel Number       Age Primary Fur Color  \
# ...

# %%
df.tail()
# Out:
#               X          Y Unique Squirrel ID Hectare Shift      Date  \
# 3018 -73.963943  40.790868     30B-AM-1007-04     30B    AM  10072018
# 3019 -73.970402  40.782560     19A-PM-1013-05     19A    PM  10132018
# 3020 -73.966587  40.783678     22D-PM-1012-07     22D    PM  10122018
# 3021 -73.963994  40.789915     29B-PM-1010-02     29B    PM  10102018
# 3022 -73.975479  40.769640      5E-PM-1012-01     05E    PM  10122018
#
#       Hectare Squirrel Number    Age Primary Fur Color  \
# 3018                        4  Adult              Gray
# 3019                        5  Adult              Gray
# 3020                        7  Adult              Gray
# 3021                        2    NaN              Gray
# 3022                        1  Adult          Cinnamon
#
#          Highlight Fur Color Combination of Primary and Highlight Color  \
# 3018                     NaN                                      Gray+
# ...

# %%
df.iloc[2:3, 1:3]
# Out:
#            Y Unique Squirrel ID
# 2  40.766718      2E-AM-1010-03

# %%
#iloc, loc
# aggregation-groupby
# data concat, merge (veri birlesimleri)

# %%
df.iloc[2:4, 1:3]
# Out:
#            Y Unique Squirrel ID
# 2  40.766718      2E-AM-1010-03
# 3  40.769703      5D-PM-1018-05

# %%
df.iloc[2:4, 1:3]
# Out:
#            Y Unique Squirrel ID
# 2  40.766718      2E-AM-1010-03
# 3  40.769703      5D-PM-1018-05

# %%
df.iloc[2,[0,5]]
# Out:
# X      -73.976831
# Date     10102018
# Name: 2, dtype: object

# %%
df.columns
# Out:
# Index(['X', 'Y', 'Unique Squirrel ID', 'Hectare', 'Shift', 'Date',
#        'Hectare Squirrel Number', 'Age', 'Primary Fur Color',
#        'Highlight Fur Color', 'Combination of Primary and Highlight Color',
#        'Color notes', 'Location', 'Above Ground Sighter Measurement',
#        'Specific Location', 'Running', 'Chasing', 'Climbing', 'Eating',
#        'Foraging', 'Other Activities', 'Kuks', 'Quaas', 'Moans', 'Tail flags',
#        'Tail twitches', 'Approaches', 'Indifferent', 'Runs from',
#        'Other Interactions', 'Lat/Long'],
#       dtype='object')

# %%
df=df.set_index("Unique Squirrel ID")

# %%
df.shape
# Out:
# (3023, 30)

# %%
df.head()
# Out:
#                             X          Y Hectare Shift      Date  \
# Unique Squirrel ID
# 37F-PM-1014-03     -73.956134  40.794082     37F    PM  10142018
# 37E-PM-1006-03     -73.957044  40.794851     37E    PM  10062018
# 2E-AM-1010-03      -73.976831  40.766718     02E    AM  10102018
# 5D-PM-1018-05      -73.975725  40.769703     05D    PM  10182018
# 39B-AM-1018-01     -73.959313  40.797533     39B    AM  10182018
#
#                     Hectare Squirrel Number       Age Primary Fur Color  \
# Unique Squirrel ID
# 37F-PM-1014-03                            3       NaN               NaN
# 37E-PM-1006-03                            3     Adult              Gray
# 2E-AM-1010-03                             3     Adult          Cinnamon
# 5D-PM-1018-05                             5  Juvenile              Gray
# 39B-AM-1018-01                            1       NaN               NaN
#
#                    Highlight Fur Color  \
# Unique Squirrel ID
# ...

# %%
df[df["X"]==-73.9703421391442]
#herhangi df de indexleme yapacaksak
# Out:
#                             X          Y Hectare Shift      Date  \
# Unique Squirrel ID
# 14D-AM-1014-01     -73.970342  40.777371     14D    AM  10142018
#
#                     Hectare Squirrel Number    Age Primary Fur Color  \
# Unique Squirrel ID
# 14D-AM-1014-01                            1  Adult              Gray
#
#                    Highlight Fur Color  \
# Unique Squirrel ID
# 14D-AM-1014-01         Cinnamon, White
#
#                    Combination of Primary and Highlight Color Color notes  \
# Unique Squirrel ID
# 14D-AM-1014-01                           Gray+Cinnamon, White         NaN
#
#                         Location Above Ground Sighter Measurement  \
# Unique Squirrel ID
# 14D-AM-1014-01      Ground Plane                            FALSE
#
#                    Specific Location  Running  Chasing  Climbing  Eating  \
# Unique Squirrel ID
# 14D-AM-1014-01                   NaN    False    False     False   False
#
# ...

# %%
df.columns
# Out:
# Index(['X', 'Y', 'Hectare', 'Shift', 'Date', 'Hectare Squirrel Number', 'Age',
#        'Primary Fur Color', 'Highlight Fur Color',
#        'Combination of Primary and Highlight Color', 'Color notes', 'Location',
#        'Above Ground Sighter Measurement', 'Specific Location', 'Running',
#        'Chasing', 'Climbing', 'Eating', 'Foraging', 'Other Activities', 'Kuks',
#        'Quaas', 'Moans', 'Tail flags', 'Tail twitches', 'Approaches',
#        'Indifferent', 'Runs from', 'Other Interactions', 'Lat/Long'],
#       dtype='object')

# %%
df[(df["Age"]=="Adult")&(df["Primary Fur Color"]=="Gray")]
# Out:
#                             X          Y Hectare Shift      Date  \
# Unique Squirrel ID
# 37E-PM-1006-03     -73.957044  40.794851     37E    PM  10062018
# 6G-PM-1020-02      -73.971974  40.769305     06G    PM  10202018
# 7B-AM-1008-09      -73.977072  40.772975     07B    AM  10082018
# 32E-PM-1017-14     -73.959641  40.790313     32E    PM  10172018
# 13E-AM-1017-05     -73.970268  40.776213     13E    AM  10172018
# ...                       ...        ...     ...   ...       ...
# 9B-AM-1010-08      -73.975916  40.773618     09B    AM  10102018
# 23C-AM-1019-01     -73.966290  40.784330     23C    AM  10192018
# 30B-AM-1007-04     -73.963943  40.790868     30B    AM  10072018
# 19A-PM-1013-05     -73.970402  40.782560     19A    PM  10132018
# 22D-PM-1012-07     -73.966587  40.783678     22D    PM  10122018
#
#                     Hectare Squirrel Number    Age Primary Fur Color  \
# Unique Squirrel ID
# 37E-PM-1006-03                            3  Adult              Gray
# ...

# %%
df.loc[(df["Age"]=="Adult")&(df["Primary Fur Color"]=="Gray"),"Hectare"]
#loc yazildiginda bir köseli parantez icinde halledebiliriz
#df[(df["Age"]=="Adult")&(df["Primary fur color"]=="Gray")]["Hectare"]
# ayni zamanda loc i diger tanimdan ayiran özellik ise loc ile birlikte yeni bir sütun(coloumn) ekleyebilmesi
# Out:
# Unique Squirrel ID
# 37E-PM-1006-03    37E
# 6G-PM-1020-02     06G
# 7B-AM-1008-09     07B
# 32E-PM-1017-14    32E
# 13E-AM-1017-05    13E
#                  ...
# 9B-AM-1010-08     09B
# 23C-AM-1019-01    23C
# 30B-AM-1007-04    30B
# 19A-PM-1013-05    19A
# 22D-PM-1012-07    22D
# Name: Hectare, Length: 2125, dtype: object

# %%
df.loc[(df["Age"]=="Adult")&(df["Primary Fur Color"]=="Gray"),"Memleket"]="Konya"

# %%
df.head()
# Out:
#                             X          Y Hectare Shift      Date  \
# Unique Squirrel ID
# 37F-PM-1014-03     -73.956134  40.794082     37F    PM  10142018
# 37E-PM-1006-03     -73.957044  40.794851     37E    PM  10062018
# 2E-AM-1010-03      -73.976831  40.766718     02E    AM  10102018
# 5D-PM-1018-05      -73.975725  40.769703     05D    PM  10182018
# 39B-AM-1018-01     -73.959313  40.797533     39B    AM  10182018
#
#                     Hectare Squirrel Number       Age Primary Fur Color  \
# Unique Squirrel ID
# 37F-PM-1014-03                            3       NaN               NaN
# 37E-PM-1006-03                            3     Adult              Gray
# 2E-AM-1010-03                             3     Adult          Cinnamon
# 5D-PM-1018-05                             5  Juvenile              Gray
# 39B-AM-1018-01                            1       NaN               NaN
#
#                    Highlight Fur Color  \
# Unique Squirrel ID
# ...

# %%
df.Memleket.value_counts(dropna=False)
# Out:
# Memleket
# Konya    2125
# NaN       898
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (3023, 31)

# %%
df.columns
# Out:
# Index(['X', 'Y', 'Hectare', 'Shift', 'Date', 'Hectare Squirrel Number', 'Age',
#        'Primary Fur Color', 'Highlight Fur Color',
#        'Combination of Primary and Highlight Color', 'Color notes', 'Location',
#        'Above Ground Sighter Measurement', 'Specific Location', 'Running',
#        'Chasing', 'Climbing', 'Eating', 'Foraging', 'Other Activities', 'Kuks',
#        'Quaas', 'Moans', 'Tail flags', 'Tail twitches', 'Approaches',
#        'Indifferent', 'Runs from', 'Other Interactions', 'Lat/Long',
#        'Memleket'],
#       dtype='object')

# %%
df.head()
# Out:
#                             X          Y Hectare Shift      Date  \
# Unique Squirrel ID
# 37F-PM-1014-03     -73.956134  40.794082     37F    PM  10142018
# 37E-PM-1006-03     -73.957044  40.794851     37E    PM  10062018
# 2E-AM-1010-03      -73.976831  40.766718     02E    AM  10102018
# 5D-PM-1018-05      -73.975725  40.769703     05D    PM  10182018
# 39B-AM-1018-01     -73.959313  40.797533     39B    AM  10182018
#
#                     Hectare Squirrel Number       Age Primary Fur Color  \
# Unique Squirrel ID
# 37F-PM-1014-03                            3       NaN               NaN
# 37E-PM-1006-03                            3     Adult              Gray
# 2E-AM-1010-03                             3     Adult          Cinnamon
# 5D-PM-1018-05                             5  Juvenile              Gray
# 39B-AM-1018-01                            1       NaN               NaN
#
#                    Highlight Fur Color  \
# Unique Squirrel ID
# ...

# %%
df.loc[(df["Age"]=="Adult")&(df["Hectare"]=="37F"),"Primary Fur Color"]="Gri"

# %%
df[df["Primary Fur Color"]=="Gri"]
# Out:
#                             X          Y Hectare Shift      Date  \
# Unique Squirrel ID
# 37F-AM-1010-01     -73.955966  40.794583     37F    AM  10102018
#
#                     Hectare Squirrel Number    Age Primary Fur Color  \
# Unique Squirrel ID
# 37F-AM-1010-01                            1  Adult               Gri
#
#                    Highlight Fur Color  \
# Unique Squirrel ID
# 37F-AM-1010-01                Cinnamon
#
#                    Combination of Primary and Highlight Color Color notes  \
# Unique Squirrel ID
# 37F-AM-1010-01                                  Gray+Cinnamon         NaN
#
#                         Location Above Ground Sighter Measurement  \
# Unique Squirrel ID
# 37F-AM-1010-01      Above Ground                                4
#
#                    Specific Location  Running  Chasing  Climbing  Eating  \
# Unique Squirrel ID
# 37F-AM-1010-01                   NaN    False    False      True   False
#
# ...

# %%
df.head()
# Out:
#                             X          Y Hectare Shift      Date  \
# Unique Squirrel ID
# 37F-PM-1014-03     -73.956134  40.794082     37F    PM  10142018
# 37E-PM-1006-03     -73.957044  40.794851     37E    PM  10062018
# 2E-AM-1010-03      -73.976831  40.766718     02E    AM  10102018
# 5D-PM-1018-05      -73.975725  40.769703     05D    PM  10182018
# 39B-AM-1018-01     -73.959313  40.797533     39B    AM  10182018
#
#                     Hectare Squirrel Number       Age Primary Fur Color  \
# Unique Squirrel ID
# 37F-PM-1014-03                            3       NaN               NaN
# 37E-PM-1006-03                            3     Adult              Gray
# 2E-AM-1010-03                             3     Adult          Cinnamon
# 5D-PM-1018-05                             5  Juvenile              Gray
# 39B-AM-1018-01                            1       NaN               NaN
#
#                    Highlight Fur Color  \
# Unique Squirrel ID
# ...

# %%
df.isnull()
# Out:
#                         X      Y  Hectare  Shift   Date  \
# Unique Squirrel ID
# 37F-PM-1014-03      False  False    False  False  False
# 37E-PM-1006-03      False  False    False  False  False
# 2E-AM-1010-03       False  False    False  False  False
# 5D-PM-1018-05       False  False    False  False  False
# 39B-AM-1018-01      False  False    False  False  False
# ...                   ...    ...      ...    ...    ...
# 30B-AM-1007-04      False  False    False  False  False
# 19A-PM-1013-05      False  False    False  False  False
# 22D-PM-1012-07      False  False    False  False  False
# 29B-PM-1010-02      False  False    False  False  False
# 5E-PM-1012-01       False  False    False  False  False
#
#                     Hectare Squirrel Number    Age  Primary Fur Color  \
# Unique Squirrel ID
# 37F-PM-1014-03                        False   True               True
# 37E-PM-1006-03                        False  False              False
# ...

# %%
df.isnull().sum(axis=0)
#axis=0 defaul degerdir ve satir bazli null degerleri toplar
#axis=1 ise sütun bazli null degerleri toplar
# Out:
# X                                                0
# Y                                                0
# Hectare                                          0
# Shift                                            0
# Date                                             0
# Hectare Squirrel Number                          0
# Age                                            121
# Primary Fur Color                               55
# Highlight Fur Color                           1086
# Combination of Primary and Highlight Color       0
# Color notes                                   2841
# Location                                        64
# Above Ground Sighter Measurement               114
# Specific Location                             2547
# Running                                          0
# Chasing                                          0
# Climbing                                         0
# Eating                                           0
# ...

# %%
df.isnull().mean()
# Out:
# X                                             0.000000
# Y                                             0.000000
# Hectare                                       0.000000
# Shift                                         0.000000
# Date                                          0.000000
# Hectare Squirrel Number                       0.000000
# Age                                           0.040026
# Primary Fur Color                             0.018194
# Highlight Fur Color                           0.359246
# Combination of Primary and Highlight Color    0.000000
# Color notes                                   0.939795
# Location                                      0.021171
# Above Ground Sighter Measurement              0.037711
# Specific Location                             0.842541
# Running                                       0.000000
# Chasing                                       0.000000
# Climbing                                      0.000000
# ...

# %%
df["Age"].value_counts(dropna=False)
# Out:
# Age
# Adult       2568
# Juvenile     330
# NaN          121
# ?              4
# Name: count, dtype: int64

# %%
df.reset_index()
# Out:
#      Unique Squirrel ID          X          Y Hectare Shift      Date  \
# 0        37F-PM-1014-03 -73.956134  40.794082     37F    PM  10142018
# 1        37E-PM-1006-03 -73.957044  40.794851     37E    PM  10062018
# 2         2E-AM-1010-03 -73.976831  40.766718     02E    AM  10102018
# 3         5D-PM-1018-05 -73.975725  40.769703     05D    PM  10182018
# 4        39B-AM-1018-01 -73.959313  40.797533     39B    AM  10182018
# ...                 ...        ...        ...     ...   ...       ...
# 3018     30B-AM-1007-04 -73.963943  40.790868     30B    AM  10072018
# 3019     19A-PM-1013-05 -73.970402  40.782560     19A    PM  10132018
# 3020     22D-PM-1012-07 -73.966587  40.783678     22D    PM  10122018
# 3021     29B-PM-1010-02 -73.963994  40.789915     29B    PM  10102018
# 3022      5E-PM-1012-01 -73.975479  40.769640     05E    PM  10122018
#
#       Hectare Squirrel Number       Age Primary Fur Color  \
# 0                           3       NaN               NaN
# ...

# %%
df.nunique()
# Out:
# X                                             3023
# Y                                             3023
# Hectare                                        339
# Shift                                            2
# Date                                            11
# Hectare Squirrel Number                         23
# Age                                              3
# Primary Fur Color                                4
# Highlight Fur Color                             10
# Combination of Primary and Highlight Color      22
# Color notes                                    135
# Location                                         2
# Above Ground Sighter Measurement                41
# Specific Location                              304
# Running                                          2
# Chasing                                          2
# Climbing                                         2
# Eating                                           2
# ...

# %%
df.shape
# Out:
# (3023, 31)

# %%
df.dtypes
# Out:
# X                                             float64
# Y                                             float64
# Hectare                                        object
# Shift                                          object
# Date                                            int64
# Hectare Squirrel Number                         int64
# Age                                            object
# Primary Fur Color                              object
# Highlight Fur Color                            object
# Combination of Primary and Highlight Color     object
# Color notes                                    object
# Location                                       object
# Above Ground Sighter Measurement               object
# Specific Location                              object
# Running                                          bool
# Chasing                                          bool
# Climbing                                         bool
# ...

# %%
df.dtypes
# Out:
# X                                             float64
# Y                                             float64
# Hectare                                        object
# Shift                                          object
# Date                                            int64
# Hectare Squirrel Number                         int64
# Age                                            object
# Primary Fur Color                              object
# Highlight Fur Color                            object
# Combination of Primary and Highlight Color     object
# Color notes                                    object
# Location                                       object
# Above Ground Sighter Measurement               object
# Specific Location                              object
# Running                                          bool
# Chasing                                          bool
# Climbing                                         bool
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                             X          Y Hectare Shift      Date  \
# Unique Squirrel ID
# 37F-PM-1014-03     -73.956134  40.794082     37F    PM  10142018
# 37E-PM-1006-03     -73.957044  40.794851     37E    PM  10062018
# 2E-AM-1010-03      -73.976831  40.766718     02E    AM  10102018
# 5D-PM-1018-05      -73.975725  40.769703     05D    PM  10182018
# 39B-AM-1018-01     -73.959313  40.797533     39B    AM  10182018
# ...                       ...        ...     ...   ...       ...
# 30B-AM-1007-04     -73.963943  40.790868     30B    AM  10072018
# 19A-PM-1013-05     -73.970402  40.782560     19A    PM  10132018
# 22D-PM-1012-07     -73.966587  40.783678     22D    PM  10122018
# 29B-PM-1010-02     -73.963994  40.789915     29B    PM  10102018
# 5E-PM-1012-01      -73.975479  40.769640     05E    PM  10122018
#
#                     Hectare Squirrel Number       Age Primary Fur Color  \
# Unique Squirrel ID
# ...

# %%
df["Date"]=pd.to_datetime(df["Date"], format='%m%d%Y', errors='coerce')

# %%
df["Date"].head()
# Out:
# Unique Squirrel ID
# 37F-PM-1014-03   2018-10-14
# 37E-PM-1006-03   2018-10-06
# 2E-AM-1010-03    2018-10-10
# 5D-PM-1018-05    2018-10-18
# 39B-AM-1018-01   2018-10-18
# Name: Date, dtype: datetime64[ns]

# %%
df.loc[(df["Age"]=="Adult")&(df["Hectare"]=="14D")&(df["Highlight Fur Color"]=="Cinnamon")]
# Out:
#                             X          Y Hectare Shift       Date  \
# Unique Squirrel ID
# 14D-PM-1019-09     -73.970811  40.777398     14D    PM 2018-10-19
# 14D-PM-1019-14     -73.970630  40.777106     14D    PM 2018-10-19
# 14D-PM-1019-16     -73.971027  40.776652     14D    PM 2018-10-19
#
#                     Hectare Squirrel Number    Age Primary Fur Color  \
# Unique Squirrel ID
# 14D-PM-1019-09                            9  Adult              Gray
# 14D-PM-1019-14                           14  Adult              Gray
# 14D-PM-1019-16                           16  Adult              Gray
#
#                    Highlight Fur Color  \
# Unique Squirrel ID
# 14D-PM-1019-09                Cinnamon
# 14D-PM-1019-14                Cinnamon
# 14D-PM-1019-16                Cinnamon
#
#                    Combination of Primary and Highlight Color Color notes  \
# Unique Squirrel ID
# 14D-PM-1019-09                                  Gray+Cinnamon         NaN
# ...

# %%
df.loc[(df["Age"]=="Juvenile")&(df["Hectare"]=="14D")|(df["Highlight Fur Color"]=="Cinnamon"),["Hectare","Age","Highlight Fur Color"]]
# Out:
#                    Hectare       Age Highlight Fur Color
# Unique Squirrel ID
# 37E-PM-1006-03         37E     Adult            Cinnamon
# 33H-AM-1019-02         33H  Juvenile            Cinnamon
# 35C-PM-1013-03         35C       NaN            Cinnamon
# 13E-AM-1017-05         13E     Adult            Cinnamon
# 11D-AM-1010-03         11D     Adult            Cinnamon
# ...                    ...       ...                 ...
# 3I-PM-1013-03          03I     Adult            Cinnamon
# 40C-AM-1017-04         40C     Adult            Cinnamon
# 25B-PM-1007-01         25B       NaN            Cinnamon
# 42H-PM-1014-04         42H     Adult            Cinnamon
# 37D-PM-1014-01         37D     Adult            Cinnamon
#
# [767 rows x 3 columns]

# %%
df.head()
# Out:
#                             X          Y Hectare Shift       Date  \
# Unique Squirrel ID
# 37F-PM-1014-03     -73.956134  40.794082     37F    PM 2018-10-14
# 37E-PM-1006-03     -73.957044  40.794851     37E    PM 2018-10-06
# 2E-AM-1010-03      -73.976831  40.766718     02E    AM 2018-10-10
# 5D-PM-1018-05      -73.975725  40.769703     05D    PM 2018-10-18
# 39B-AM-1018-01     -73.959313  40.797533     39B    AM 2018-10-18
#
#                     Hectare Squirrel Number       Age Primary Fur Color  \
# Unique Squirrel ID
# 37F-PM-1014-03                            3       NaN               NaN
# 37E-PM-1006-03                            3     Adult              Gray
# 2E-AM-1010-03                             3     Adult          Cinnamon
# 5D-PM-1018-05                             5  Juvenile              Gray
# 39B-AM-1018-01                            1       NaN               NaN
#
#                    Highlight Fur Color  \
# Unique Squirrel ID
# ...

# %%
df.reset_index()
# Out:
#      Unique Squirrel ID          X          Y Hectare Shift       Date  \
# 0        37F-PM-1014-03 -73.956134  40.794082     37F    PM 2018-10-14
# 1        37E-PM-1006-03 -73.957044  40.794851     37E    PM 2018-10-06
# 2         2E-AM-1010-03 -73.976831  40.766718     02E    AM 2018-10-10
# 3         5D-PM-1018-05 -73.975725  40.769703     05D    PM 2018-10-18
# 4        39B-AM-1018-01 -73.959313  40.797533     39B    AM 2018-10-18
# ...                 ...        ...        ...     ...   ...        ...
# 3018     30B-AM-1007-04 -73.963943  40.790868     30B    AM 2018-10-07
# 3019     19A-PM-1013-05 -73.970402  40.782560     19A    PM 2018-10-13
# 3020     22D-PM-1012-07 -73.966587  40.783678     22D    PM 2018-10-12
# 3021     29B-PM-1010-02 -73.963994  40.789915     29B    PM 2018-10-10
# 3022      5E-PM-1012-01 -73.975479  40.769640     05E    PM 2018-10-12
#
#       Hectare Squirrel Number       Age Primary Fur Color  \
# ...

# %%
df.columns
# Out:
# Index(['X', 'Y', 'Hectare', 'Shift', 'Date', 'Hectare Squirrel Number', 'Age',
#        'Primary Fur Color', 'Highlight Fur Color',
#        'Combination of Primary and Highlight Color', 'Color notes', 'Location',
#        'Above Ground Sighter Measurement', 'Specific Location', 'Running',
#        'Chasing', 'Climbing', 'Eating', 'Foraging', 'Other Activities', 'Kuks',
#        'Quaas', 'Moans', 'Tail flags', 'Tail twitches', 'Approaches',
#        'Indifferent', 'Runs from', 'Other Interactions', 'Lat/Long',
#        'Memleket'],
#       dtype='object')

# %%
df[df['Combination of Primary and Highlight Color']=="White"]
# Out:
# Empty DataFrame
# Columns: [X, Y, Hectare, Shift, Date, Hectare Squirrel Number, Age, Primary Fur Color, Highlight Fur Color, Combination of Primary and Highlight Color, Color notes, Location, Above Ground Sighter Measurement, Specific Location, Running, Chasing, Climbing, Eating, Foraging, Other Activities, Kuks, Quaas, Moans, Tail flags, Tail twitches, Approaches, Indifferent, Runs from, Other Interactions, Lat/Long, Memleket]
# Index: []

# %%
df[df['Combination of Primary and Highlight Color'].str.contains("White")]
#sütunu stringe cevirip girdigimiz degeri icerip icermedigini sorgulayabiliriz
# Out:
#                             X          Y Hectare Shift       Date  \
# Unique Squirrel ID
# 11H-AM-1010-03     -73.968361  40.772591     11H    AM 2018-10-10
# 20B-PM-1013-05     -73.969506  40.782351     20B    PM 2018-10-13
# 16C-PM-1018-03     -73.970378  40.778753     16C    PM 2018-10-18
# 17F-AM-1007-07     -73.967113  40.778486     17F    AM 2018-10-07
# 16I-AM-1008-01     -73.964987  40.776493     16I    AM 2018-10-08
# ...                       ...        ...     ...   ...        ...
# 23C-AM-1019-01     -73.966290  40.784330     23C    AM 2018-10-19
# 19A-PM-1013-05     -73.970402  40.782560     19A    PM 2018-10-13
# 22D-PM-1012-07     -73.966587  40.783678     22D    PM 2018-10-12
# 29B-PM-1010-02     -73.963994  40.789915     29B    PM 2018-10-10
# 5E-PM-1012-01      -73.975479  40.769640     05E    PM 2018-10-12
#
#                     Hectare Squirrel Number    Age Primary Fur Color  \
# Unique Squirrel ID
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
df[df['Combination of Primary and Highlight Color'].str.contains("White")]
# Out:
#                             X          Y Hectare Shift       Date  \
# Unique Squirrel ID
# 11H-AM-1010-03     -73.968361  40.772591     11H    AM 2018-10-10
# 20B-PM-1013-05     -73.969506  40.782351     20B    PM 2018-10-13
# 16C-PM-1018-03     -73.970378  40.778753     16C    PM 2018-10-18
# 17F-AM-1007-07     -73.967113  40.778486     17F    AM 2018-10-07
# 16I-AM-1008-01     -73.964987  40.776493     16I    AM 2018-10-08
# ...                       ...        ...     ...   ...        ...
# 23C-AM-1019-01     -73.966290  40.784330     23C    AM 2018-10-19
# 19A-PM-1013-05     -73.970402  40.782560     19A    PM 2018-10-13
# 22D-PM-1012-07     -73.966587  40.783678     22D    PM 2018-10-12
# 29B-PM-1010-02     -73.963994  40.789915     29B    PM 2018-10-10
# 5E-PM-1012-01      -73.975479  40.769640     05E    PM 2018-10-12
#
#                     Hectare Squirrel Number    Age Primary Fur Color  \
# Unique Squirrel ID
# ...

# %%
liste=[2,3,4,5,6]
list(map(lambda x:x**2, liste))
# Out:
# [4, 9, 16, 25, 36]

# %%
df[Hectare].head()
# Out:
# Unique Squirrel ID
# 37F-PM-1014-03    37F
# 37E-PM-1006-03    37E
# 2E-AM-1010-03     02E
# 5D-PM-1018-05     05D
# 39B-AM-1018-01    39B
# Name: Hectare, dtype: object

# %%
df['Hectare']=df['Hectare'].apply(lambda x: x.lstrip('0'))
# apply pd.series'lere(sütunlar) bi de df'lere(sütunlarin tamamina) uygulanir.
# apply tek tek sütun elemanlari alir ve icine yazilan fonksiyonu tek tek uygular. 
# map iterater'lara uygulanir
# lstrip ilki siler, arstrip sondakini siler.

# %%
df['Hectare'].head()
# Out:
# Unique Squirrel ID
# 37F-PM-1014-03    37F
# 37E-PM-1006-03    37E
# 2E-AM-1010-03      2E
# 5D-PM-1018-05      5D
# 39B-AM-1018-01    39B
# Name: Hectare, dtype: object

# %%
# df e komple apply uygularsak ne olur bunu arastir
